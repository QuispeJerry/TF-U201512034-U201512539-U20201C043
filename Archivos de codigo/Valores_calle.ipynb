# %%
import math

def bF(G, s):
  n = len(G)
  a = [-1]*n
  g = [math.inf]*n
  g[s] = 0

  for _ in range(n-1):
    for u in range(n):
      for v, w in G[u]:
        f = g[u] + w
        if f < g[v]:
          g[v] = f
          a[v] = u

  for u in range(n):
    for v, w in G[u]:
      f = g[u] + w
      if f < g[v]:
        return None, None

  return a, g

# %%
# !git clone https://github.com/lmcanavals/acomplex.git
# Out:
# fatal: destination path 'acomplex' already exists and is not an empty directory.

# %%
from acomplex import graphstuff as gs

# %% [markdown]
# ```
# w -> 0
# x -> 1
# y -> 2
# z -> 3
# ```

# %%
# %%file valores.al
# 3 2
# 0 6 2 3
# 0 4 3 5
# 1 -7 2 -3
# Out:
# Writing valores.al

# %%
G = gs.loadGraphAL("valores.al")
labels = "WXYZ"
gs.adjlShow(G, labels, directed=True, weighted=True, layout="circo")
